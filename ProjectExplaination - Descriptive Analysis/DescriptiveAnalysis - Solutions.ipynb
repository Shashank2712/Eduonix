# %% [markdown]
# # Descriptive Statistics with Python Project
#
#
# **Descriptive Statistics** is the subject matter of this project. Descriptive statistics gives us the basic summary measures about the dataset.  The summary measures include measures of central tendency (mean, median and mode) and measures of variability (variance, standard deviation, minimum/maximum values, IQR (Interquartile Range), skewness and kurtosis). I have used the fortune 500 dataset from the data world website for this project.

# %% [markdown]
# ## Table of Contents
#
#
# 1.	Introduction to descriptive statistics
#
# 2.	Measures of central tendency
#     -	Mean
#
#     -	Median
#
#     -	Mode
#
#
# 3.	Measures of dispersion
#     -	Variance
#
#     -	Standard deviation
#
#     -	Coefficient of variation
#
#     -	IQR (Interquartile range)
#
#     -	Skewness
#
#     -	Kurtosis
#
#
# 4.	Dataset description
#
# 5.	Import libraries
#
# 6.	Import dataset
#
# 7.	Exploratory data analysis
#
# 8.	Descriptive statistics with `describe()` function
#     -	Summary statistics of numerical columns
#
#     -	Summary statistics of character columns
#
#     -	Summary statistics of all the columns
#
#
# 9.	Computation of measures of central tendency
#     -	Mean
#
#     -	Median
#
#     -	Mode
#
#
# 10.	Computation of measures of dispersion or variability
#     -	Minimum and maximum values
#
#     -	Range
#
#     -	Variance
#
#     -	Standard deviation
#
#     -	Median
#
#     -	Interquartile Range
#
#
# 11.	Computation of measures of shape of distribution
#     -	Skewness
#
#     -	Kurtosis
#
#
# 12.	Results and conclusion

# %% [markdown]
# ## 1. Introduction to descriptive statistics
#
#
# Descriptive statistics are numbers that are used to describe and summarize the data. They are used to describe the basic features of the data under consideration. They provide simple summary measures which give an overview of the dataset. Summary measures that are commonly used to describe a data set are measures of central tendency and measures of variability or dispersion.
#
#
# Measures of central tendency include the `mean`, `median` and `mode`. These measures summarize a given data set by providing a single data point. These measures describe the center position of a distribution for a data set. We analyze the frequency of each data point in the distribution and describes it using the mean, median or mode. They provide the average of a data set. They can be either a representation of entire population or a sample of the population.
#
#
# Measures of variability or dispersion include the `variance` or `standard deviation`, `coefficient of variation`,  `minimum` and `maximum` values, `IQR (Interquartile Range)`,  `skewness and `kurtosis`. These measures help us to analyze how spread-out the distribution is for a dataset. So, they provide the shape of the data set.

# %% [markdown]
# ## 2. Measures of central tendency
#
#
# **Central tendency** means a central value which describe a probability distribution. It may also be called a center or location of the distribution. The most common measures of central tendency are **mean**, **median** and **mode**. The most common measure of central tendency is the **mean**. For skewed distribution or when there is concern about outliers, the **median** may be preferred. So, median is more robust measure than the mean.
#
#
#
# ### Mean
#
# - The most common measure of central tendency is the mean.
# - Mean is also known as the simple average.
# - It is denoted by greek letter µ for population and by ¯x for sample.
# - We can find mean of a number of elements by adding all the elements in a dataset and then dividing by the number of elements  in the dataset.
# - It is the most common measure of central tendency but it has a drawback.
# - The mean is affected by the presence of outliers.
# - So, mean alone is not enough for making business decisions.
#
#
# ### Median
#
# - Median is the number which divides the dataset into two equal halves.
# - To calculate the median, we have to arrange our dataset of n numbers in ascending order.
# - The median of this dataset is the number at (n+1)/2 th position, if n is odd.
# - If n is even, then the median is the average of the (n/2)th number and (n+2)/2 th number.
# - Median is robust to outliers.
# - So, for skewed distribution or when there is concern about outliers, the median may be preferred.
#
#
# ### Mode
#
# - Mode of a dataset is the value that occurs most often in the dataset.
# - Mode is the value that has the highest frequency of occurrence in the dataset.
#
#
# There is no best measure that give us the complete picture. So, these measures of central tendency (mean, median and mode) should be used together to represent the full picture.

# %% [markdown]
# ## 3. Measures of dispersion or variability
#
#
# **Dispersion** is an indicator of how far away from the center, we can find the data values. The most common measures of dispersion are **variance**, **standard deviation** and **interquartile range (IQR)**. **Variance** is the standard measure of spread. The **standard deviation** is the square root of the variance. The **variance** and **standard deviation** are two useful measures of spread.
#
#
#
# ### Variance
#
# -	Variance measures the dispersion of a set of data points around their mean value.
#
# -	It is the mean of the squares of the individual deviations.
#
# -	Variance gives results in the original units squared.
#
#
#
# ### Standard deviation
#
# -	Standard deviation is the most common used measure of variability.
#
# -	It is the square-root of the variance.
#
# -	For Normally distributed data, approximately 95% of the values lie within 2 s.d. of the mean.
#
# -	Standard deviation gives results in the original units.
#
#
# ### Coefficient of Variation (CV)
#
# -	Coefficient of Variation (CV) is equal to the standard deviation divided by the mean.
#
# -	It is also known as `relative standard deviation`.
#
#
# ### IQR (Interquartile range)
#
# -	A third measure of spread is the **interquartile range (IQR)**.
#
# -	The IQR is calculated using the boundaries of data situated between the 1st and the 3rd quartiles.
#
# -	The interquartile range (IQR) can be calculated as follows:-
#        IQR = Q3 – Q1
#
# -	In the same way that the median is more robust than the mean, the IQR is a more robust measure of spread than variance and standard deviation and should therefore be preferred for small or asymmetrical distributions.
#
# -	It is a robust measure of spread.
#
#
#
# ### Measures of shape
#
# Now, we will take a look at measures of shape of distribution. There are two statistical measures that can tell us about the shape of the distribution. These measures are **skewness** and **kurtosis**. These measures can be used to convey information about the shape of the distribution of the dataset.
#
#
# ### Skewness
# -	**Skewness** is a measure of a distribution's symmetry or more precisely lack of symmetry.
#
# -	It is used to mean the absence of symmetry from the mean of the dataset.
#
# -	It is a characteristic of the deviation from the mean.
#
# -	It is used to indicate the shape of the distribution of data.
#
#
# #### Negative skewness
#
# -	Negative values for skewness indicate negative skewness.
#
# -	In this case, the data are skewed or tail to left.
#
# -	By skewed left, we mean that the left tail is long relative to the right tail.
#
# -	The data values may extend further to the left but concentrated in the right.
#
# -	So, there is a long tail and distortion is caused by extremely small values which pull the mean downward so that it is less than the median.
#
# -	Hence, in this case we have
#       **Mean < Median < Mode**
#
#
# #### Zero skewness
#
# -	Zero skewness means skewness value of zero.
#
# -	It means the dataset is symmetrical.
#
# -	A data set is symmetrical if it looks the same to the left and right to the center point.
#
# -	The dataset looks bell shaped or symmetrical.
#
# -	A perfectly symmetrical data set will have a skewness of zero.
#
# -	So, the normal distribution which is perfectly symmetrical has a skewness of 0.
# -	So, in this case, we have
#       **Mean = Median = Mode**
#
#
# #### Positive skewness
#
# -	Positive values for skewness indicate positive skewness.
#
# -	The dataset are skewed or tail to right.
#
# -	By skewed right, we mean that the right tail is long relative to the left tail.
#
# -	The data values are concentrated in the right.
#
# -	So, there is a long tail to the right that is caused by extremely large values which pull the mean upward so that it is greater than the median.
#
# -	So, we have
#        **Mean > Median > Mode**
#
#
# #### Reference range on skewness values
#
# The rule of thumb for skewness values are:
#
# -	If the skewness is between -0.5 and 0.5, the data are fairly symmetrical.
#
# -	If the skewness is between -1 and – 0.5 or between 0.5 and 1, the data are moderately skewed.
#
# -	If the skewness is less than -1 or greater than 1, the data are highly skewed.
#
#
# ### Kurtosis
#
# -	Kurtosis is the degree of peakedness of a distribution.
#
# -	Data sets with high kurtosis tend to have a distinct peak near the mean, decline rather rapidly and have heavy tails.
#
# -	Data sets with low kurtosis tend to have a flat top near the mean rather than a sharp peak.
#
#
# #### Reference range for kurtosis
# -	The reference standard is a normal distribution, which has a kurtosis of 3.
#
# -	Often, **excess kurtosis** is presented instead of kurtosis, where **excess kurtosis** is simply **kurtosis - 3**.
#
# #### Mesokurtic curve
# -	A normal distribution has kurtosis exactly 3 (**excess kurtosis** exactly 0).
#
# -	Any distribution with kurtosis ≈3 (excess ≈ 0) is called **mesokurtic**.
#
# #### Platykurtic curve
# -	A distribution with kurtosis < 3 (**excess kurtosis** < 0) is called **platykurtic**.
#
# -	As compared to a normal distribution, its central peak is lower and broader, and its tails are shorter and thinner.
#
# #### Leptokurtic curve
#
# -	A distribution with kurtosis > 3 (**excess kurtosis** > 0) is called **leptokurtic**.
#
# -	As compared to a normal distribution, its central peak is higher and sharper, and its tails are longer and fatter.
#
#
#
# ### Summary
#
#
# So far, we have looked at the measures of central tendency of the data which include `mean`, `median` and `mode`. Also, we have taken a look at measures of spread of the data which consists of `variance`, `standard deviation`, `interquartile range (IQR)`, `minimum` and `maximum` values. We have also discussed `skewness` and `kurtosis` as measures of shape. These quantities can only be used for quantitative variables not for categorical variables.

# %% [markdown]
# ## 4. Dataset description
#
#
# I have used the `fortune 500 dataset` for this project. I have downloaded this dataset from the data world website. This data set can be downloaded from the following url –
#
#
# https://data.world/alexandra/fortune-500
#
#
# The data set consists of revenue and profit figures of fortune 500 companies along with their rank.

# %% [markdown]
# ## 5. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Ignore warnings

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# ## 6. Import dataset

# %%
#data = 'C:/datasets/fortune500.csv'

df = pd.read_csv('Ff500.csv')

# %% [markdown]
# ## 7. Exploratory data analysis
#
#
# Now, I will explore the data to gain insights about the data.

# %% [markdown]
# ### View dimensions of dataset

# %%
#find the shape of dataset
df.shape
# Out:
# (500, 23)

# %% [markdown]
# We can see that there are 500 instances and 23 variables in the data set.

# %% [markdown]
# ### Preview the dataset

# %%
df = pd.DataFrame(df)

# %%
#check top 5 columns of the dataset
df.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  Hqzip         Hqtel  \
# 0     702 S.W. Eighth St.    Bentonville      AR  72716  479-273-4000
# 1         3555 Farnam St.          Omaha      NE  68131  402-346-1400
# 2         1 Infinite Loop      Cupertino      CA  95014  408-996-1010
# 3  5959 Las Colinas Blvd.         Irving      TX  75039  972-444-1000
# 4              1 Post St.  San Francisco      CA  94104  415-983-8300
#
#                    Ceo                                      Ceo-title  \
# 0  C. Douglas McMillon  President, Chief Executive Officer & Director
# 1    Warren E. Buffett             Chairman & Chief Executive Officer
# 2      Timothy D. Cook             Chief Executive Officer & Director
# 3      Darren W. Woods             Chairman & Chief Executive Officer
# 4   John H. Hammergren  Chairman, President & Chief Executive Officer
#
#                                       Address Ticker                 Fullname  \
# 0  702 S.W. Eighth St., Bentonville, AR 72716    WMT    Wal-Mart Stores, Inc.
# 1            3555 Farnam St., Omaha, NE 68131   BRKA  Berkshire Hathaway Inc.
# 2        1 Infinite Loop, Cupertino, CA 95014   AAPL              Apple, Inc.
# 3    5959 Las Colinas Blvd., Irving, TX 75039    XOM  Exxon Mobil Corporation
# 4         1 Post St., San Francisco, CA 94104    MCK     McKesson Corporation
#
#    Revenues  Revchange  Profits Prftchange  Assets  Totshequity
# 0    485873        0.8  13643.0       -7.2  198825      77798.0
# 1    223604        6.1  24074.0          0  620854     283001.0
# 2    215639       -7.7  45687.0      -14.4  321686     128249.0
# 3    205004      -16.7   7840.0      -51.5  330314     167325.0
# 4    192487        6.2   2258.0         53   56563       8924.0

# %% [markdown]
# ### View summary of dataset

# %%
#summary
df.info
# Out:
# <bound method DataFrame.info of      Rank                                   Title  \
# 0       1                                 Walmart
# 1       2                      Berkshire Hathaway
# 2       3                                   Apple
# 3       4                             Exxon Mobil
# 4       5                                McKesson
# 5       6                      UnitedHealth Group
# 6       7                              CVS Health
# 7       8                          General Motors
# 8       9                                    AT&T
# 9      10                              Ford Motor
# 10     11                       AmerisourceBergen
# 11     12                              Amazon.com
# 12     13                        General Electric
# 13     14                                 Verizon
# 14     15                         Cardinal Health
# 15     16                                  Costco
# 16     17                Walgreens Boots Alliance
# 17     18                                  Kroger
# 18     19                                 Chevron
# 19     20                              Fannie Mae
# 20     21                       J.P. Morgan Chase
# 21     22                 Express Scripts Holding
# 22     23                              Home Depot
# 23     24                                  Boeing
# 24     25                             Wells Fargo
# 25     26                   Bank of America Corp.
# 26     27                                Alphabet
# 27     28                               Microsoft
# 28     29                                  Anthem
# 29     30                               Citigroup
# 30     31                                 Comcast
# 31     32                                     IBM
# 32     33               State Farm Insurance Cos.
# 33     34                             Phillips 66
# 34     35                       Johnson & Johnson
# 35     36                        Procter & Gamble
# 36     37                           Valero Energy
# 37     38                                  Target
# 38     39                             Freddie Mac
# 39     40                                  Lowe’s
# 40     41                       Dell Technologies
# 41     42                                 MetLife
# 42     43                                   Aetna
# 43     44                                 PepsiCo
# 44     45                  Archer Daniels Midland
# 45     46                                     UPS
# 46     47                                   Intel
# 47     48                    Prudential Financial
# 48     49                         Albertsons Cos.
# 49     50                     United Technologies
# 50     51                      Marathon Petroleum
# 51     52                                  Disney
# 52     53                                  Humana
# 53     54                                  Pfizer
# 54     55                                     AIG
# 55     56                         Lockheed Martin
# 56     57                                   Sysco
# 57     58                                   FedEx
# 58     59              Hewlett Packard Enterprise
# 59     60                           Cisco Systems
# 60     61                                      HP
# 61     62                            Dow Chemical
# 62     63                            HCA Holdings
# 63     64                               Coca-Cola
# 64     65                 New York Life Insurance
# 65     66                                 Centene
# 66     67                 American Airlines Group
# 67     68                              Nationwide
# 68     69                                   Merck
# 69     70                                   Cigna
# 70     71                         Delta Air Lines
# 71     72                                Best Buy
# 72     73                 Honeywell International
# 73     74                             Caterpillar
# 74     75          Liberty Mutual Insurance Group
# 75     76                          Morgan Stanley
# 76     77     Massachusetts Mutual Life Insurance
# 77     78                     Goldman Sachs Group
# 78     79                  Energy Transfer Equity
# 79     80                                    TIAA
# 80     81                                  Oracle
# 81     82                             Tyson Foods
# 82     83             United Continental Holdings
# 83     84                                Allstate
# 84     85                    Publix Super Markets
# 85     86                        American Express
# 86     87                                     TJX
# 87     88                                    Nike
# 88     89                                  Exelon
# 89     90                        General Dynamics
# 90     91                                Rite Aid
# 91     92                         Gilead Sciences
# 92     93                                     CHS
# 93     94                                      3M
# 94     95                             Time Warner
# 95     96                  Charter Communications
# 96     97                     Northwestern Mutual
# 97     98                                Facebook
# 98     99                          Travelers Cos.
# 99    100                   Capital One Financial
# 100   101                Twenty-First Century Fox
# 101   102                                    USAA
# 102   103                     World Fuel Services
# 103   104             Philip Morris International
# 104   105                                   Deere
# 105   106                             Kraft Heinz
# 106   107                               Tech Data
# 107   108                                   Avnet
# 108   109                  Mondelez International
# 109   110                                  Macy’s
# 110   111                                  AbbVie
# 111   112                              McDonald’s
# 112   113                                  DuPont
# 113   114                        Northrop Grumman
# 114   115                          ConocoPhillips
# 115   116                                Raytheon
# 116   117                                  Tesoro
# 117   118                       Arrow Electronics
# 118   119                                Qualcomm
# 119   120                             Progressive
# 120   121                             Duke Energy
# 121   122            Enterprise Products Partners
# 122   123                                   Amgen
# 123   124                        US Foods Holding
# 124   125                            U.S. Bancorp
# 125   126                                   Aflac
# 126   127                          Sears Holdings
# 127   128                          Dollar General
# 128   129                              AutoNation
# 129   130                Community Health Systems
# 130   131                               Starbucks
# 131   132                               Eli Lilly
# 132   133                     International Paper
# 133   134                        Tenet Healthcare
# 134   135                     Abbott Laboratories
# 135   136                             Dollar Tree
# 136   137                               Whirlpool
# 137   138                      Southwest Airlines
# 138   139                        Emerson Electric
# 139   140                                 Staples
# 140   141                      Plains GP Holdings
# 141   142                 Penske Automotive Group
# 142   143                           Union Pacific
# 143   144                                 Danaher
# 144   145                                Southern
# 145   146                           ManpowerGroup
# 146   147                    Bristol-Myers Squibb
# 147   148                            Altria Group
# 148   149                                   Fluor
# 149   150                                  Kohl’s
# 150   151                                    Lear
# 151   152                           Jabil Circuit
# 152   153       Hartford Financial Services Group
# 153   154                Thermo Fisher Scientific
# 154   155                          Kimberly-Clark
# 155   156                       Molina Healthcare
# 156   157                              PG&E Corp.
# 157   158                               Supervalu
# 158   159                                 Cummins
# 159   160                             CenturyLink
# 160   161                                   AECOM
# 161   162                                   Xerox
# 162   163                  Marriott International
# 163   164                                  Paccar
# 164   165                           General Mills
# 165   166            PNC Financial Services Group
# 166   167                 American Electric Power
# 167   168                       Icahn Enterprises
# 168   169                                   Nucor
# 169   170                          NextEra Energy
# 170   171                  Performance Food Group
# 171   172                              PBF Energy
# 172   173                             Halliburton
# 173   174                                  CarMax
# 174   175                        Freeport-McMoRan
# 175   176                      Whole Foods Market
# 176   177                 Bank of New York Mellon
# 177   178                                     Gap
# 178   179                           Omnicom Group
# 179   180                           Genuine Parts
# 180   181                                  DaVita
# 181   182                       Colgate-Palmolive
# 182   183                          PPG Industries
# 183   184                  Goodyear Tire & Rubber
# 184   185                     Synchrony Financial
# 185   186                            DISH Network
# 186   187                                    Visa
# 187   188                               Nordstrom
# 188   189                            INTL FCStone
# 189   190                                WestRock
# 190   191                           XPO Logistics
# 191   192                                 Aramark
# 192   193                                     CBS
# 193   194                                     AES
# 194   195                   WellCare Health Plans
# 195   196                             FirstEnergy
# 196   197                          Conagra Brands
# 197   198                                  Synnex
# 198   199                                     CDW
# 199   200                                 Textron
# 200   201                        Waste Management
# 201   202                     Illinois Tool Works
# 202   203                            Office Depot
# 203   204                                Monsanto
# 204   205          Cognizant Technology Solutions
# 205   206                       Texas Instruments
# 206   207                        Lincoln National
# 207   208                           Newell Brands
# 208   209                            Land O’Lakes
# 209   210                        Marsh & McLennan
# 210   211                                  Ecolab
# 211   212                 C.H. Robinson Worldwide
# 212   213                                   Loews
# 213   214                              CBRE Group
# 214   215                           Kinder Morgan
# 215   216                                 Kellogg
# 216   217                         Western Digital
# 217   218       Guardian Life Ins. Co. of America
# 218   219                             Ross Stores
# 219   220                                L Brands
# 220   221                             J.C. Penney
# 221   222              Farmers Insurance Exchange
# 222   223                       Reynolds American
# 223   224                                  Viacom
# 224   225                        Becton Dickinson
# 225   226                       Micron Technology
# 226   227                     Principal Financial
# 227   228                                 Arconic
# 228   229                              NRG Energy
# 229   230                                      VF
# 230   231                            Devon Energy
# 231   232                             D.R. Horton
# 232   233                       Bed Bath & Beyond
# 233   234                     Consolidated Edison
# 234   235                    Edison International
# 235   236                        Sherwin-Williams
# 236   237                     NGL Energy Partners
# 237   238                         Dominion Energy
# 238   239                    Ameriprise Financial
# 239   240                                     ADP
# 240   241               Hilton Worldwide Holdings
# 241   242                              First Data
# 242   243                            Henry Schein
# 243   244                             Toys “R” Us
# 244   245                              BB&T Corp.
# 245   246            Reinsurance Group of America
# 246   247                       Core-Mark Holding
# 247   248                                  Biogen
# 248   249                         Las Vegas Sands
# 249   250                  Stanley Black & Decker
# 250   251                         Parker-Hannifin
# 251   252                                 Stryker
# 252   253                            Estee Lauder
# 253   254                                 Celgene
# 254   255                               BlackRock
# 255   256                             Xcel Energy
# 256   257                                     CSX
# 257   258                              Unum Group
# 258   259                Jacobs Engineering Group
# 259   260                                  Lennar
# 260   261                      Group 1 Automotive
# 261   262                       Leucadia National
# 262   263                                 Entergy
# 263   264                         PayPal Holdings
# 264   265                       Applied Materials
# 265   266                          Voya Financial
# 266   267                              Mastercard
# 267   268                         Priceline Group
# 268   269                     Liberty Interactive
# 269   270                                AutoZone
# 270   271                      State Street Corp.
# 271   272                              DTE Energy
# 272   273                         L3 Technologies
# 273   274                           HollyFrontier
# 274   275                                 Praxair
# 275   276               Universal Health Services
# 276   277             Discover Financial Services
# 277   278                    Occidental Petroleum
# 278   279                     United States Steel
# 279   280                           Sempra Energy
# 280   281                    Baxter International
# 281   282                           W.W. Grainger
# 282   283                                 Autoliv
# 283   284                        Norfolk Southern
# 284   285                            Baker Hughes
# 285   286                          Ally Financial
# 286   287                        Sonic Automotive
# 287   288                           Owens & Minor
# 288   289                                Huntsman
# 289   290             Laboratory Corp. of America
# 290   291                              Murphy USA
# 291   292                      Advance Auto Parts
# 292   293             Fidelity National Financial
# 293   294                Air Products & Chemicals
# 294   295                            Hormel Foods
# 295   296                   Hertz Global Holdings
# 296   297               MGM Resorts International
# 297   298                                 Corning
# 298   299                       Republic Services
# 299   300                                   Alcoa
# 300   301  Fidelity National Information Services
# 301   302                            Pacific Life
# 302   303                          SunTrust Banks
# 303   304                                     LKQ
# 304   305                              BorgWarner
# 305   306                                    Ball
# 306   306                              CST Brands
# 307   306         Public Service Enterprise Group
# 308   309                        Eastman Chemical
# 309   310                                    eBay
# 310   311                       Mohawk Industries
# 311   312                                   Oneok
# 312   313                 Frontier Communications
# 313   314                                 Netflix
# 314   315         American Family Insurance Group
# 315   316        Thrivent Financial for Lutherans
# 316   317                                 Expedia
# 317   318                           Lithia Motors
# 318   319                       Avis Budget Group
# 319   320               Reliance Steel & Aluminum
# 320   321                                GameStop
# 321   322                                 Tenneco
# 322   323                     O’Reilly Automotive
# 323   324                      Peter Kiewit Sons’
# 324   325                    United Natural Foods
# 325   326                          salesforce.com
# 326   327                       Boston Scientific
# 327   328                          Newmont Mining
# 328   329                      Genworth Financial
# 329   330               Live Nation Entertainment
# 330   331                                 Veritiv
# 331   332                              News Corp.
# 332   333                          Crown Holdings
# 333   334                         Global Partners
# 334   335                                     PVH
# 335   336                  Level 3 Communications
# 336   337                  Navistar International
# 337   338                                  Univar
# 338   339                           Campbell Soup
# 339   340                   Dick’s Sporting Goods
# 340   341                            Weyerhaeuser
# 341   342               Mutual of Omaha Insurance
# 342   343                       Chesapeake Energy
# 343   344                      Anadarko Petroleum
# 344   345                       Interpublic Group
# 345   346                            J.M. Smucker
# 346   347                          Steel Dynamics
# 347   348                             Foot Locker
# 348   349                        Western Refining
# 349   350                             SpartanNash
# 350   351                              Dean Foods
# 351   352                  Zimmer Biomet Holdings
# 352   353                              PulteGroup
# 353   354                            W.R. Berkley
# 354   355                         Quanta Services
# 355   356                           EOG Resources
# 356   357                          Charles Schwab
# 357   358                       Eversource Energy
# 358   359                   Anixter International
# 359   360                             EMCOR Group
# 360   361                                Assurant
# 361   362                      CenterPoint Energy
# 362   363                                  Harris
# 363   364                      HD Supply Holdings
# 364   365                                     PPL
# 365   366                       Quest Diagnostics
# 366   367                                Williams
# 367   368                        WEC Energy Group
# 368   369                                 Hershey
# 369   370                                    AGCO
# 370   371                            Ralph Lauren
# 371   372                                   Masco
# 372   373                     WESCO International
# 373   374                        LifePoint Health
# 374   375                  National Oilwell Varco
# 375   376                      Kindred Healthcare
# 376   377                                  Mosaic
# 377   378                   Alliance Data Systems
# 378   379                       Computer Sciences
# 379   380           Huntington Ingalls Industries
# 380   381                         Leidos Holdings
# 381   382                    Erie Insurance Group
# 382   383                                   Tesla
# 383   384                     Ascena Retail Group
# 384   385                      Darden Restaurants
# 385   386         Harman International Industries
# 386   387                                  Nvidia
# 387   388                   R.R. Donnelley & Sons
# 388   389                     Fifth Third Bancorp
# 389   390                  Quintiles IMS Holdings
# 390   391                      Jones Lang LaSalle
# 391   392                                   Dover
# 392   393             Spirit AeroSystems Holdings
# 393   394                            Ryder System
# 394   395                  A-Mark Precious Metals
# 395   396                          Tractor Supply
# 396   397                              Sealed Air
# 397   398                   Auto-Owners Insurance
# 398   399                      Yum China Holdings
# 399   400                                 Calpine
# 400   401                          Owens-Illinois
# 401   402                         Targa Resources
# 402   403          Jones Financial (Edward Jones)
# 403   403                         JetBlue Airways
# 404   405                      Franklin Resources
# 405   406                     Activision Blizzard
# 406   407            J.B. Hunt Transport Services
# 407   408                    Constellation Brands
# 408   409                                     NCR
# 409   410                 Asbury Automotive Group
# 410   411                American Financial Group
# 411   412                Discovery Communications
# 412   413                      Berry Global Group
# 413   414                                 Sanmina
# 414   415                       CalAtlantic Group
# 415   416                 Dr Pepper Snapple Group
# 416   417                               Dillard’s
# 417   418                               HRG Group
# 418   419                              CMS Energy
# 419   420                        Graybar Electric
# 420   421                    Builders FirstSource
# 421   422                              Yum Brands
# 422   423                  Casey’s General Stores
# 423   424                                Amphenol
# 424   425                                 Oshkosh
# 425   426                             iHeartMedia
# 426   427                         TreeHouse Foods
# 427   428                               Alleghany
# 428   429  Expeditors International of Washington
# 429   430                          Avery Dennison
# 430   431                                  Ameren
# 431   432                             Hanesbrands
# 432   433                      Motorola Solutions
# 433   434                        St. Jude Medical
# 434   435                         Harley-Davidson
# 435   436                       Regions Financial
# 436   437               Intercontinental Exchange
# 437   438                        Alaska Air Group
# 438   439              Old Republic International
# 439   440                            Lam Research
# 440   441                        AK Steel Holding
# 441   442                     Rockwell Automation
# 442   443                           Adobe Systems
# 443   444                           Avon Products
# 444   445                                   Terex
# 445   446                                     NVR
# 446   447                                    Dana
# 447   448                        Realogy Holdings
# 448   449                          American Tower
# 449   450              Packaging Corp. of America
# 450   451                Citizens Financial Group
# 451   452                          United Rentals
# 452   453                                  Clorox
# 453   454                      Genesis Healthcare
# 454   455                          M&T Bank Corp.
# 455   456                               Ingredion
# 456   457                                     UGI
# 457   458                           Owens Corning
# 458   459                              S&P Global
# 459   460                                  Markel
# 460   461                       Wyndham Worldwide
# 461   462                     Arthur J. Gallagher
# 462   463                       Burlington Stores
# 463   464                First American Financial
# 464   465                                Symantec
# 465   466                               Patterson
# 466   467                                    Olin
# 467   468                                  NetApp
# 468   469                 Raymond James Financial
# 469   470                TravelCenters of America
# 470   471                                  Fiserv
# 471   472                   Host Hotels & Resorts
# 472   473                     Insight Enterprises
# 473   474                                  Mattel
# 474   475              AmTrust Financial Services
# 475   476                    Cincinnati Financial
# 476   477                    Simon Property Group
# 477   478                           Western Union
# 478   479                                 KeyCorp
# 479   480                       Delek US Holdings
# 480   481             Booz Allen Hamilton Holding
# 481   482                                Chemours
# 482   483      Western & Southern Financial Group
# 483   484                                Celanese
# 484   485                     Windstream Holdings
# 485   486                                Seaboard
# 486   487                               Essendant
# 487   488                                  Apache
# 488   489                                  Airgas
# 489   490                          Kelly Services
# 490   491                           Liberty Media
# 491   492                        Rockwell Collins
# 492   493               Robert Half International
# 493   494                               CH2M Hill
# 494   495                                Big Lots
# 495   496                           Michaels Cos.
# 496   497                           Toll Brothers
# 497   498                                   Yahoo
# 498   499                           Vistra Energy
# 499   500                          ABM Industries
#
#                                       Website  Employees  \
# 0                      http://www.walmart.com    2300000
# 1            http://www.berkshirehathaway.com     367700
# 2                        http://www.apple.com     116000
# 3                   http://www.exxonmobil.com      72700
# 4                     http://www.mckesson.com      68000
# 5            http://www.unitedhealthgroup.com     230000
# 6                    http://www.cvshealth.com     204000
# 7                           http://www.gm.com     225000
# 8                          http://www.att.com     268540
# 9                         http://www.ford.com     201000
# 10           http://www.amerisourcebergen.com      18500
# 11                      http://www.amazon.com     341400
# 12                          http://www.ge.com     295000
# 13                     http://www.verizon.com     160900
# 14              http://www.cardinalhealth.com      37300
# 15                      http://www.costco.com     172000
# 16      http://www.walgreensbootsalliance.com     300000
# 17                 http://www.thekrogerco.com     443000
# 18                     http://www.chevron.com      55200
# 19                   http://www.fanniemae.com       7000
# 20               http://www.jpmorganchase.com     243355
# 21             http://www.express-scripts.com      25600
# 22                   http://www.homedepot.com     406000
# 23                      http://www.boeing.com     150540
# 24                  http://www.wellsfargo.com     269100
# 25               http://www.bankofamerica.com     208024
# 26                         http://www.abc.xyz      72053
# 27                   http://www.microsoft.com     114000
# 28                   http://www.antheminc.com      53000
# 29                   http://www.citigroup.com     219000
# 30          http://www.comcastcorporation.com     159000
# 31                         http://www.ibm.com     414400
# 32                   http://www.statefarm.com      68234
# 33                  http://www.phillips66.com      14800
# 34                         http://www.jnj.com     126400
# 35                          http://www.pg.com     105000
# 36                      http://www.valero.com       9996
# 37                      http://www.target.com     323000
# 38                  http://www.freddiemac.com       5982
# 39                       http://www.lowes.com     240000
# 40            http://www.delltechnologies.com     138000
# 41                     http://www.metlife.com      58000
# 42                       http://www.aetna.com      49500
# 43                     http://www.pepsico.com     264000
# 44                         http://www.adm.com      31800
# 45                         http://www.ups.com     335520
# 46                       http://www.intel.com     106000
# 47                  http://www.prudential.com      49739
# 48                  http://www.albertsons.com     274000
# 49                         http://www.utc.com     201600
# 50           http://www.marathonpetroleum.com      44460
# 51                      http://www.disney.com     195000
# 52                      http://www.humana.com      51600
# 53                      http://www.pfizer.com      96500
# 54                         http://www.aig.com      56400
# 55              http://www.lockheedmartin.com      97000
# 56                       http://www.sysco.com      51900
# 57                       http://www.fedex.com     335767
# 58                         http://www.hpe.com     195000
# 59                       http://www.cisco.com      73700
# 60                          http://www.hp.com      49000
# 61                         http://www.dow.com      56000
# 62               http://www.hcahealthcare.com     210500
# 63            http://www.coca-colacompany.com     100300
# 64                 http://www.newyorklife.com      11320
# 65                     http://www.centene.com      30500
# 66                          http://www.aa.com     122300
# 67                  http://www.nationwide.com      34320
# 68                       http://www.merck.com      68000
# 69                       http://www.cigna.com      41000
# 70                       http://www.delta.com      83756
# 71                     http://www.bestbuy.com     125000
# 72                   http://www.honeywell.com     131000
# 73                 http://www.caterpillar.com      95400
# 74               http://www.libertymutual.com      50000
# 75               http://www.morganstanley.com      55311
# 76                  http://www.massmutual.com      11737
# 77                          http://www.gs.com      34400
# 78              http://www.energytransfer.com      30992
# 79                        http://www.tiaa.org      12997
# 80                      http://www.oracle.com     136000
# 81                  http://www.tysonfoods.com     114000
# 82   http://www.unitedcontinentalholdings.com      88000
# 83                    http://www.allstate.com      43275
# 84                      http://www.publix.com     191000
# 85             http://www.americanexpress.com      56400
# 86                         http://www.tjx.com     235000
# 87                        http://www.nike.com      70700
# 88                  http://www.exeloncorp.com      34396
# 89             http://www.generaldynamics.com      98800
# 90                     http://www.riteaid.com      70580
# 91                      http://www.gilead.com       9000
# 92                      http://www.chsinc.com      12157
# 93                          http://www.3m.com      91584
# 94                  http://www.timewarner.com      25000
# 95                     http://www.charter.com      91500
# 96          http://www.northwesternmutual.com       5646
# 97                    http://www.facebook.com      17048
# 98                   http://www.travelers.com      30900
# 99                  http://www.capitalone.com      47300
# 100                       http://www.21cf.com      21500
# 101                       http://www.usaa.com      29943
# 102                    http://www.wfscorp.com       5000
# 103                        http://www.pmi.com      79500
# 104                  http://www.johndeere.com      56767
# 105          http://www.kraftheinzcompany.com      41000
# 106                   http://www.techdata.com       9500
# 107                      http://www.avnet.com      17700
# 108      http://www.mondelezinternational.com      90000
# 109                   http://www.macysinc.com     148300
# 110                     http://www.abbvie.com      30000
# 111             http://www.aboutmcdonalds.com     375000
# 112                     http://www.dupont.com      46000
# 113            http://www.northropgrumman.com      67000
# 114             http://www.conocophillips.com      13300
# 115                   http://www.raytheon.com      63000
# 116                    http://www.tsocorp.com       6308
# 117                      http://www.arrow.com      18700
# 118                   http://www.qualcomm.com      30500
# 119                http://www.progressive.com      31721
# 120                http://www.duke-energy.com      28798
# 121         http://www.enterpriseproducts.com       6800
# 122                      http://www.amgen.com      19200
# 123                    http://www.usfoods.com      25000
# 124                     http://www.usbank.com      71191
# 125                      http://www.aflac.com      10212
# 126              http://www.searsholdings.com     140000
# 127              http://www.dollargeneral.com     121000
# 128                 http://www.autonation.com      26000
# 129                        http://www.chs.net     108000
# 130                  http://www.starbucks.com     254000
# 131                      http://www.lilly.com      41975
# 132         http://www.internationalpaper.com      55000
# 133                http://www.tenethealth.com     116475
# 134                     http://www.abbott.com      75000
# 135                 http://www.dollartree.com     116050
# 136              http://www.whirlpoolcorp.com      93000
# 137                  http://www.southwest.com      53536
# 138                    http://www.emerson.com     103500
# 139                    http://www.staples.com      61503
# 140          http://www.plainsallamerican.com       5100
# 141           http://www.penskeautomotive.com      24000
# 142                         http://www.up.com      42919
# 143                    http://www.danaher.com      62000
# 144            http://www.southerncompany.com      32015
# 145              http://www.manpowergroup.com      28000
# 146                        http://www.bms.com      25000
# 147                     http://www.altria.com       8300
# 148                      http://www.fluor.com      61551
# 149                      http://www.kohls.com      85000
# 150                       http://www.lear.com     148400
# 151                      http://www.jabil.com     138000
# 152                http://www.thehartford.com      16900
# 153               http://www.thermofisher.com      54800
# 154             http://www.kimberly-clark.com      42000
# 155           http://www.molinahealthcare.com      21000
# 156                    http://www.pgecorp.com      24000
# 157                  http://www.supervalu.com      38000
# 158                    http://www.cummins.com      55400
# 159                http://www.centurylink.com      40000
# 160                      http://www.aecom.com      87000
# 161                      http://www.xerox.com     133600
# 162                   http://www.marriott.com     226500
# 163                     http://www.paccar.com      23000
# 164               http://www.generalmills.com      39000
# 165                        http://www.pnc.com      50683
# 166                        http://www.aep.com      17634
# 167                       http://www.ielp.com      90980
# 168                      http://www.nucor.com      23900
# 169              http://www.nexteraenergy.com      14700
# 170                       http://www.pfgc.com      13000
# 171                  http://www.pbfenergy.com       3165
# 172                http://www.halliburton.com      50000
# 173                     http://www.carmax.com      22429
# 174                        http://www.fcx.com      30000
# 175           http://www.wholefoodsmarket.com      73515
# 176                  http://www.bnymellon.com      52000
# 177                     http://www.gapinc.com     135000
# 178               http://www.omnicomgroup.com      78500
# 179                      http://www.genpt.com      40000
# 180                     http://www.davita.com      70300
# 181           http://www.colgatepalmolive.com      36700
# 182                        http://www.ppg.com      47000
# 183                   http://www.goodyear.com      66000
# 184         http://www.synchronyfinancial.com      15000
# 185                       http://www.dish.com      16000
# 186                       http://www.visa.com      14200
# 187                  http://www.nordstrom.com      72500
# 188                http://www.intlfcstone.com       1464
# 189                   http://www.westrock.com      39000
# 190                        http://www.xpo.com      87000
# 191                    http://www.aramark.com     217250
# 192             http://www.cbscorporation.com      18410
# 193                        http://www.aes.com      19000
# 194                   http://www.wellcare.com       7400
# 195            http://www.firstenergycorp.com      15707
# 196              http://www.conagrabrands.com      20900
# 197                     http://www.synnex.com     110000
# 198                        http://www.cdw.com       8516
# 199                    http://www.textron.com      36000
# 200                         http://www.wm.com      41200
# 201                        http://www.itw.com      50000
# 202                http://www.officedepot.com      38000
# 203                   http://www.monsanto.com      22450
# 204                  http://www.cognizant.com     260200
# 205                         http://www.ti.com      29865
# 206                        http://www.lfg.com       9057
# 207               http://www.newellbrands.com      53400
# 208              http://www.landolakesinc.com      10000
# 209                        http://www.mmc.com      60000
# 210                     http://www.ecolab.com      47565
# 211                 http://www.chrobinson.com      14125
# 212                      http://www.loews.com      15800
# 213                       http://www.cbre.com      75000
# 214               http://www.kindermorgan.com      11121
# 215             http://www.kelloggcompany.com      37369
# 216             http://www.westerndigital.com      72878
# 217               http://www.guardianlife.com       8876
# 218                 http://www.rossstores.com      78600
# 219                         http://www.lb.com      59100
# 220                   http://www.jcpenney.com     106000
# 221                    http://www.farmers.com      13309
# 222           http://www.reynoldsamerican.com       5525
# 223                     http://www.viacom.com       9650
# 224                         http://www.bd.com      50928
# 225                     http://www.micron.com      31400
# 226                  http://www.principal.com      14854
# 227                    http://www.arconic.com      41500
# 228                        http://www.nrg.com       8763
# 229                        http://www.vfc.com      69000
# 230                http://www.devonenergy.com       3545
# 231                   http://www.drhorton.com       6976
# 232           http://www.bedbathandbeyond.com      62000
# 233                  http://www.conedison.com      14960
# 234             http://www.edisoninvestor.com      12390
# 235                    http://www.sherwin.com      42550
# 236          http://www.nglenergypartners.com       3200
# 237             http://www.dominionenergy.com      16200
# 238                 http://www.ameriprise.com      13195
# 239                        http://www.adp.com      57000
# 240            http://www.hiltonworldwide.com     169000
# 241                  http://www.firstdata.com      24000
# 242                http://www.henryschein.com      21000
# 243                 http://www.toysrusinc.com      64000
# 244                        http://www.bbt.com      37500
# 245                      http://www.rgare.com       2371
# 246                  http://www.core-mark.com       7688
# 247                     http://www.biogen.com       7400
# 248                      http://www.sands.com      49000
# 249      http://www.stanleyblackanddecker.com      54023
# 250                     http://www.parker.com      48950
# 251                    http://www.stryker.com      33000
# 252                http://www.elcompanies.com      46000
# 253                    http://www.celgene.com       7132
# 254                  http://www.blackrock.com      13000
# 255                 http://www.xcelenergy.com      11476
# 256                        http://www.csx.com      26628
# 257                       http://www.unum.com       9400
# 258                     http://www.jacobs.com      49350
# 259                     http://www.lennar.com       8335
# 260                 http://www.group1auto.com      13500
# 261                   http://www.leucadia.com      13000
# 262                    http://www.entergy.com      13513
# 263                     http://www.paypal.com      18100
# 264           http://www.appliedmaterials.com      16150
# 265                       http://www.voya.com       6700
# 266                 http://www.mastercard.com      11900
# 267             http://www.pricelinegroup.com      18500
# 268         http://www.libertyinteractive.com      21080
# 269                   http://www.autozone.com      66780
# 270                http://www.statestreet.com      33783
# 271                  http://www.dteenergy.com      10000
# 272                        http://www.l3t.com      38000
# 273              http://www.hollyfrontier.com       2676
# 274                    http://www.praxair.com      26498
# 275                     http://www.uhsinc.com      70863
# 276                   http://www.discover.com      15549
# 277                        http://www.oxy.com      11000
# 278                    http://www.ussteel.com      29800
# 279                     http://www.sempra.com      16575
# 280                     http://www.baxter.com      48000
# 281                   http://www.grainger.com      25000
# 282                    http://www.autoliv.com      65900
# 283                     http://www.nscorp.com      27856
# 284                http://www.bakerhughes.com      33000
# 285                       http://www.ally.com       7600
# 286            http://www.sonicautomotive.com       9800
# 287                http://www.owens-minor.com       7900
# 288                   http://www.huntsman.com      15000
# 289                    http://www.labcorp.com      52000
# 290                  http://www.murphyusa.com       6600
# 291           http://www.advanceautoparts.com      57500
# 292                        http://www.fnf.com      55219
# 293                http://www.airproducts.com      18450
# 294                http://www.hormelfoods.com      21100
# 295                      http://www.hertz.com      36000
# 296                 http://www.mgmresorts.com      66500
# 297                    http://www.corning.com      40700
# 298           http://www.republicservices.com      33000
# 299                      http://www.alcoa.com      14000
# 300                  http://www.fisglobal.com      55000
# 301                http://www.pacificlife.com       3628
# 302                   http://www.suntrust.com      24375
# 303                    http://www.lkqcorp.com      42500
# 304                 http://www.borgwarner.com      27000
# 305                       http://www.ball.com      18450
# 306                  http://www.cstbrands.com      12380
# 307                       http://www.pseg.com      13065
# 308                    http://www.eastman.com      14000
# 309                       http://www.ebay.com      12600
# 310                  http://www.mohawkind.com      37800
# 311                      http://www.oneok.com       2384
# 312                   http://www.frontier.com      28332
# 313                    http://www.netflix.com       3850
# 314                      http://www.amfam.com      10471
# 315                   http://www.thrivent.com       3282
# 316                 http://www.expediainc.com      20075
# 317               http://www.lithiamotors.com      11170
# 318            http://www.avisbudgetgroup.com      25600
# 319                       http://www.rsac.com      14500
# 320               http://www.gamestopcorp.com      41750
# 321                    http://www.tenneco.com      31000
# 322                http://www.oreillyauto.com      58397
# 323                     http://www.kiewit.com      20000
# 324                       http://www.unfi.com       9554
# 325                 http://www.salesforce.com      25000
# 326           http://www.bostonscientific.com      27000
# 327                    http://www.newmont.com      12438
# 328                   http://www.genworth.com       3400
# 329    http://www.livenationentertainment.com      11500
# 330                http://www.veritivcorp.com       8700
# 331                   http://www.newscorp.com      24000
# 332                  http://www.crowncork.com      23992
# 333                    http://www.globalp.com       1770
# 334                        http://www.pvh.com      26650
# 335                     http://www.level3.com      12600
# 336                   http://www.navistar.com      11300
# 337                     http://www.univar.com       8700
# 338        http://www.campbellsoupcompany.com      16500
# 339                      http://www.dicks.com      27550
# 340               http://www.weyerhaeuser.com      10400
# 341              http://www.mutualofomaha.com       5732
# 342                        http://www.chk.com       3300
# 343                   http://www.anadarko.com       4500
# 344                http://www.interpublic.com      49800
# 345                  http://www.jmsmucker.com       6910
# 346              http://www.steeldynamics.com       7695
# 347             http://www.footlocker-inc.com      32965
# 348                        http://www.wnr.com       7134
# 349                http://www.spartannash.com      11500
# 350                  http://www.deanfoods.com      17000
# 351               http://www.zimmerbiomet.com      18500
# 352              http://www.pultegroupinc.com       4623
# 353                  http://www.wrberkley.com       7608
# 354             http://www.quantaservices.com      28100
# ...
# 167  -1128.0      -70.2    33335       2154.0
# 168    796.3      122.6    15224       7880.0
# 169   2912.0        5.8    89993      24341.0
# 170     68.3       20.9     3455        803.0
# 171    170.8       16.7     7622       2025.0
# 172  -5763.0       16.7    27000       9409.0
# 173    623.4        4.4    14482       2905.0
# 174  -4154.0        4.4    37317       6051.0
# 175    507.0       -5.4     6341       3224.0
# 176   3547.0       12.3   333469      38811.0
# 177    676.0      -26.5     7610       2904.0
# 178   1148.6          5    23165       2162.0
# 179    687.2       -2.6     8859       3194.0
# 479   -153.7     -892.3     2985        992.0
# 480    294.1       26.5     3010        409.0
# 481      7.0       26.5     6060        100.0
# 482    241.2      -47.2    43831       5104.0
# 483    900.0      196.1     8357       2588.0
# 484   -383.5  -1,499.60    11770        170.0
# 485    312.0       82.5     4755       3162.0
# 486     63.9       82.5     2164        781.0
# 487  -1405.0       82.5    22519       6238.0
# 488    337.5       -8.3     6135       2045.0
# 489    120.8      124.5     2028       1012.0
# 490    680.0      962.5    31377      11756.0
# 491    728.0        6.1     7707       2078.0
# 492    343.4         -4     1778       1087.0
# 493     15.0      -81.3     2671        547.0
# 494    152.8          7     1608        651.0
# 495    378.2        4.2     2148      -1698.0
# 496    382.1        5.2     9737       4229.0
# 497   -214.3        5.2    48083      31049.0
# 498   -214.3        5.2    15167       6597.0
# 499     57.2        -25     2281        974.0  >

# %% [markdown]
# ### Observations
#
# - We can see that the `Year` and `Rank` variables have integer data types as expected. The `Company` variable is of object data type.
#
# - The `Revenue (in millions)` variable is of float data type.
#
# - The `Profit (in millions)` variable is of object data type.

# %% [markdown]
# ### Check for missing values

# %%
#check for null values
df.isnull().sum()
# Out:
# Rank           0
# Title          0
# Website        0
# Employees      0
# Sector         0
# Industry       0
# Hqlocation     0
# Hqaddr         0
# Hqcity         0
# Hqstate        0
# Hqzip          0
# Hqtel          0
# Ceo            0
# Ceo-title      0
# Address        0
# Ticker         0
# Fullname       0
# Revenues       0
# Revchange      0
# Profits        0
# Prftchange     0
# Assets         0
# Totshequity    0
# dtype: int64

# %% [markdown]
# The above command shows that there are no missing values in the dataset.

# %% [markdown]
# ## 8. Descriptive statistics with `describe()` function
#
#
#
# Descriptive or summary statistics in python – pandas, can be obtained by using the `describe()` function. The `describe()` function gives us the `count`, `mean`, `standard deviation(std)`, `minimum`, `Q1(25%)`, `median(50%)`, `Q3(75%)`, `IQR(Q3 - Q1)` and `maximum` values.
#
#
# I will demonstrate the usage of `describe()` function as follows.

# %% [markdown]
# ### Summary statistics of numerical columns

# %%
#all statistical measures
df.describe()
# Out:
#              Rank     Employees         Hqzip       Revenues  Revchange  \
# count  500.000000  5.000000e+02    500.000000     500.000000  500.00000
# mean   250.492000  5.635013e+04  46791.714000   24111.748000    3.75800
# std    144.477366  1.234520e+05  30160.384765   38337.353337   19.96748
# min      1.000000  8.300000e+01   1104.000000    5145.000000  -57.50000
# 25%    125.750000  1.190000e+04  19099.000000    7245.000000   -3.82500
# 50%    250.500000  2.500000e+04  46244.500000   11384.000000    1.90000
# 75%    375.250000  5.682525e+04  75045.000000   22605.250000    7.32500
# max    500.000000  2.300000e+06  98188.000000  485873.000000  197.30000
#
#             Profits        Assets  Totshequity
# count    500.000000  5.000000e+02     500.0000
# mean    1779.479800  8.038934e+04   13640.1470
# std     3937.558721  2.704257e+05   30523.1538
# min    -6177.000000  4.370000e+02  -12688.0000
# 25%      235.725000  8.436500e+03    1997.5000
# 50%      683.600000  1.932450e+04    4981.0000
# 75%     1770.775000  4.812600e+04   12467.7500
# max    45687.000000  3.287968e+06  283001.0000

# %% [markdown]
# We can see that the `describe()` function excludes the character columns and gives summary statistics of numeric columns only.

# %% [markdown]
# ### Summary statistics of character columns
#
#
# - The `describe()` function with an argument named `include` along with `value` object(include='object') gives the summary statistics of the character columns.

# %%
df.describe(include='object')
# Out:
#           Title                Website      Sector  \
# count       500                    500         500
# unique      500                    499          21
# top     Walmart  http://www.abbott.com  Financials
# freq          1                      2          84
#
#                            Industry    Hqlocation               Hqaddr  \
# count                           500           500                  500
# unique                           73           246                  491
# top     Utilities: Gas and Electric  New York, NY  12300 Liberty Blvd.
# freq                             22            45                    2
#
#           Hqcity Hqstate         Hqtel              Ceo  \
# count        500     500           500              500
# unique       239      37           499              496
# top     New York      NY  650-857-1501  Gregory J. Goff
# freq          45      54             2                2
#
#                                             Ceo-title  \
# count                                             500
# unique                                             12
# top     President, Chief Executive Officer & Director
# freq                                              189
#
#                                      Address Ticker               Fullname  \
# count                                    500    500                    500
# unique                                   494    468                    500
# top     400 Atlantic St., Stamford, CT 06901   NFLX  Wal-Mart Stores, Inc.
# freq                                       2      3                      1
#
#        Prftchange
# count         500
# unique        377
# top           5.2
# freq            6

# %% [markdown]
# ### Summary statistics of all the columns
#
#
# - The `describe()` function with include='all' gives the summary statistics of all the columns.
#
#
# - We need to add a variable named include='all' to get the summary statistics or descriptive statistics of both numeric and character columns.

# %%
df.describe(include='all')
# Out:
#               Rank    Title                Website     Employees      Sector  \
# count   500.000000      500                    500  5.000000e+02         500
# unique         NaN      500                    499           NaN          21
# top            NaN  Walmart  http://www.abbott.com           NaN  Financials
# freq           NaN        1                      2           NaN          84
# mean    250.492000      NaN                    NaN  5.635013e+04         NaN
# std     144.477366      NaN                    NaN  1.234520e+05         NaN
# min       1.000000      NaN                    NaN  8.300000e+01         NaN
# 25%     125.750000      NaN                    NaN  1.190000e+04         NaN
# 50%     250.500000      NaN                    NaN  2.500000e+04         NaN
# 75%     375.250000      NaN                    NaN  5.682525e+04         NaN
# max     500.000000      NaN                    NaN  2.300000e+06         NaN
#
#                            Industry    Hqlocation               Hqaddr  \
# count                           500           500                  500
# unique                           73           246                  491
# top     Utilities: Gas and Electric  New York, NY  12300 Liberty Blvd.
# freq                             22            45                    2
# mean                            NaN           NaN                  NaN
# std                             NaN           NaN                  NaN
# min                             NaN           NaN                  NaN
# 25%                             NaN           NaN                  NaN
# 50%                             NaN           NaN                  NaN
# 75%                             NaN           NaN                  NaN
# max                             NaN           NaN                  NaN
#
#           Hqcity Hqstate         Hqzip         Hqtel              Ceo  \
# count        500     500    500.000000           500              500
# unique       239      37           NaN           499              496
# top     New York      NY           NaN  650-857-1501  Gregory J. Goff
# freq          45      54           NaN             2                2
# mean         NaN     NaN  46791.714000           NaN              NaN
# std          NaN     NaN  30160.384765           NaN              NaN
# min          NaN     NaN   1104.000000           NaN              NaN
# 25%          NaN     NaN  19099.000000           NaN              NaN
# 50%          NaN     NaN  46244.500000           NaN              NaN
# 75%          NaN     NaN  75045.000000           NaN              NaN
# max          NaN     NaN  98188.000000           NaN              NaN
#
#                                             Ceo-title  \
# count                                             500
# unique                                             12
# top     President, Chief Executive Officer & Director
# freq                                              189
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
#                                      Address Ticker               Fullname  \
# count                                    500    500                    500
# unique                                   494    468                    500
# top     400 Atlantic St., Stamford, CT 06901   NFLX  Wal-Mart Stores, Inc.
# freq                                       2      3                      1
# mean                                     NaN    NaN                    NaN
# std                                      NaN    NaN                    NaN
# min                                      NaN    NaN                    NaN
# 25%                                      NaN    NaN                    NaN
# 50%                                      NaN    NaN                    NaN
# 75%                                      NaN    NaN                    NaN
# max                                      NaN    NaN                    NaN
#
#              Revenues  Revchange       Profits Prftchange        Assets  \
# count      500.000000  500.00000    500.000000        500  5.000000e+02
# unique            NaN        NaN           NaN        377           NaN
# top               NaN        NaN           NaN        5.2           NaN
# freq              NaN        NaN           NaN          6           NaN
# mean     24111.748000    3.75800   1779.479800        NaN  8.038934e+04
# std      38337.353337   19.96748   3937.558721        NaN  2.704257e+05
# min       5145.000000  -57.50000  -6177.000000        NaN  4.370000e+02
# 25%       7245.000000   -3.82500    235.725000        NaN  8.436500e+03
# 50%      11384.000000    1.90000    683.600000        NaN  1.932450e+04
# 75%      22605.250000    7.32500   1770.775000        NaN  4.812600e+04
# max     485873.000000  197.30000  45687.000000        NaN  3.287968e+06
#
#         Totshequity
# count      500.0000
# unique          NaN
# top             NaN
# freq            NaN
# mean     13640.1470
# std      30523.1538
# min     -12688.0000
# 25%       1997.5000
# 50%       4981.0000
# 75%      12467.7500
# max     283001.0000

# %% [markdown]
# ## 9. Computation of measures of central tendency
#
#
# - In this section, I will compute the measures of central tendency - mean, median and mode.
#
# - These statistics give us a approximate value of the middle of a numeric variable.
#
# - I will use the `Revenue (in millions)` variable for calculations.

# %% [markdown]
# ### Mean

# %%
#mean of Revenue (in millions)

revenue_mean = df['Revenues'].mean()
print('The mean of Revenue (in millions) : ', revenue_mean)
# Out:
# The mean of Revenue (in millions) :  24111.748

# %% [markdown]
# ### Median

# %%
#median of Revenue (in millions)

revenue_median = df['Revenues'].median()
print('The median of Revenue (in millions) : ', revenue_median)
# Out:
# The median of Revenue (in millions) :  11384.0

# %% [markdown]
# ### Mode

# %%
##mode of Revenue (in millions)

revenue_mode = df['Revenues'].mode()
print('The mode of Revenue (in millions) : ', revenue_mode)
# Out:
# The mode of Revenue (in millions) :  0    9061
# Name: Revenues, dtype: int64

# %% [markdown]
# ### Observation
#
#
# - We can see that `mean > median > mode`. So, the distribution of `Revenue (in millions)` is positively skewed. I will plot its distribution to confirm the same.

# %% [markdown]
# ### Plot the distribution

# %%
data = df['Revenue (in millions)']

sns.distplot(data, bins=10, hist=True, kde=True, label = 'Revenue (in millions)')
# Out:
# <Axes: xlabel='Revenue (in millions)', ylabel='Density'>

# %% [markdown]
# The above plot confirms that the `Revenue (in millions)` is positively skewed.

# %%
data = df['Revenues']
plt.show()
sns.distplot(data, bins=10, hist=True, kde=True, label = 'Revenue (in millions)')
# Out:
# <Axes: xlabel='Revenues', ylabel='Density'>

# %% [markdown]
# ## 10. Computation of measures of dispersion or variability
#
#
# - In this section, I will compute the measures of dispersion or variability - minimum and maximum values, range, variance, standard-deviation, IQR.
#
# - Again, I will use the `Revenue (in millions)` variable for calculations.

# %% [markdown]
# ### Minimum value

# %%
# check min of Revenue (in millions)

print('The minimum value of Revenue is : ',df['Revenues'].min())
# Out:
# The minimum value of Revenue is :  5145

# %% [markdown]
# ### Maximum value

# %%
# check min of Revenue (in millions)
print('The maximum value of Revenue is : ',df['Revenues'].max())
# Out:
# The maximum value of Revenue is :  485873

# %% [markdown]
# ### Range

# %%
# check range of Revenue (in millions)
revenue_range = df['Revenues'].max() - df['Revenues'].min()

print("The Revenue range is : ", revenue_range)
# Out:
# The Revenue range is :  480728

# %%
revenue_range = np.ptp(df['Revenues'])

print("The Revenue range is : ", revenue_range)
# Out:
# The Revenue range is :  480728

# %% [markdown]
# ### Variance

# %%
# check variance of Revenue (in millions)
revenue_var = df['Revenues'].var()
print("The variance of Revenue is : ",revenue_var )
# Out:
# The variance of Revenue is :  1469752660.8501961

# %% [markdown]
# ### Standard deviation

# %%
# check sd of Revenue (in millions)
revenue_stdvar = df['Revenues'].std()
print("The variance of Revenue is : ",revenue_stdvar )
# Out:
# The variance of Revenue is :  38337.35333653324

# %% [markdown]
# ### Median (Q2 or 50th percentile)

# %%
# check q2 of Revenue (in millions)

print("The Q2 of revenue is : ", df['Revenues'].median())
# Out:
# The Q2 of revenue is :  11384.0

# %% [markdown]
# ### Q3 or 75th percentile

# %%
# check q3 of Revenue (in millions)

print("The Q3 of revenue is : ", df['Revenues'].quantile(0.75))
# Out:
# The Q3 of revenue is :  22605.25

# %% [markdown]
# ### Q1 or 25th percentile

# %%
# check q1 of Revenue (in millions)
print("The Q1 of revenue is : ", df['Revenues'].quantile(0.25))
# Out:
# The Q1 of revenue is :  7245.0

# %% [markdown]
# ### Interquartile Range

# %%
# check iqr of Revenue (in millions)

print("The Inter Quantile Range os revenues is : ",df['Revenues'].quantile(0.75) - df['Revenues'].quantile(0.25) )
# Out:
# The Inter Quantile Range os revenues is :  15360.25

# %% [markdown]
# ### Draw boxplot

# %%
# check boxplot of Revenue (in millions)

plt.show()

# %%
plt.show()
sns.boxplot(df['Revenues'])
# Out:
# <Axes: >

# %% [markdown]
# ## 11. Computation of measures of shape of distribution
#
#
# - In this section, I will compute the measures of shape of distribution - skewness and kurtosis.
#
# - Again, I will use the `Revenue (in millions)` variable for calculations.

# %% [markdown]
# ### Skewness

# %%
# check skewness of Revenue (in millions)
print("The skewness of revenues is : ", df['Revenues'].skew())
# Out:
# The skewness of revenues is :  5.480066970305041

# %% [markdown]
# ### Interpretation
#
# I find the skewness to be 9.3267. So, it is greater than 1. Hence, we can conclude that the `Revenue (in millions)` data is highly skewed.

# %% [markdown]
# ### Kurtosis

# %%
# check kurtosis of Revenue (in millions)

print("The kurtosis of revenues is : ", df['Revenues'].kurtosis())
# Out:
# The kurtosis of revenues is :  47.58795634430753

# %% [markdown]
# ### Interpretation
#
# I find the kurtosis to be 132.0456. So, it is greater than 3 and so excess kurtosis > 0. Hence, we can conclude that the `Revenue (in millions)` curve is a leptokurtic curve. As compared to a normal distribution, its central peak is higher and sharper, and its tails are longer and fatter.

# %% [markdown]
# ## 12. Results and conclusion
#
#
# 1.	In this project, I describe the descriptive statistics that are used to summarize a dataset.
#
# 2.	In particular, I have described the measures of central tendency (mean, median and mode). I have also described the measures of dispersion or variability (variance, standard deviation, coefficient of variation, minimum and maximum values, IQR) and measures of shape (skewness and kurtosis).
#
# 3.	I have demonstrated how to calculate the summary statistics with `describe()` function.
#
# 4.	I have computed the measures of central tendency-mean, median and mode for the `Revenue (in millions)`variable. I have found `mean > median > mode`. So, the distribution of `Revenue (in millions)` is positively skewed. I have plotted its distribution to confirm the same.
#
# 5.	I have computed the measures of dispersion or variability-range, variance, standard-deviation, median and IQR for the `Revenue (in millions)`variable.
#
# 6.	I have also computed the measures of shape-skewness and kurtosis for the `Revenue (in millions)`variable.
# 7.	I find the skewness to be 9.3267. So, it is greater than 1. Hence, we can conclude that the `Revenue (in millions)` data is highly skewed.
#
# 8.	I find the kurtosis to be 132.0456. So, it is greater than 3 and so excess kurtosis > 0. Hence, we can conclude that the `Revenue (in millions)` curve is a leptokurtic curve. As compared to a normal distribution, its central peak is higher and sharper, and its tails are longer and fatter.

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Website', 'Employees', 'Sector', 'Industry',
#        'Hqlocation', 'Hqaddr', 'Hqcity', 'Hqstate', 'Hqzip', 'Hqtel', 'Ceo',
#        'Ceo-title', 'Address', 'Ticker', 'Fullname', 'Revenues', 'Revchange',
#        'Profits', 'Prftchange', 'Assets', 'Totshequity'],
#       dtype='object')

# %%
# check valuecounts of Revenue (in millions)
print("The value counts of revenues is : ", df['Revenues'].value_counts())
# Out:
# The value counts of revenues is :  Revenues
# 9061      3
# 7651      2
# 6632      2
# 12394     2
# 485873    1
# 8203      1
# 8319      1
# 8284      1
# 8240      1
# 8111      1
# 8172      1
# 8355      1
# 8074      1
# 7961      1
# 7922      1
# 7902      1
# 8327      1
# 8369      1
# 7872      1
# 8379      1
# 8386      1
# 8392      1
# 8470      1
# 8573      1
# 8593      1
# 8599      1
# 8608      1
# 8613      1
# 8659      1
# 8678      1
# 8774      1
# 8777      1
# 7899      1
# 7847      1
# 7869      1
# 7532      1
# 7336      1
# 7357      1
# 7405      1
# 7411      1
# 7440      1
# 7472      1
# 7499      1
# 7515      1
# 7517      1
# 7524      1
# 7527      1
# 7528      1
# 7552      1
# 8831      1
# 7625      1
# 7639      1
# 7644      1
# 7654      1
# 7669      1
# 7684      1
# 7710      1
# 7735      1
# 7743      1
# 7766      1
# 7777      1
# 7811      1
# 8829      1
# 8896      1
# 7251      1
# 8921      1
# 10398     1
# 10497     1
# 10508     1
# 10534     1
# 10536     1
# 10597     1
# 10630     1
# 10635     1
# 10636     1
# 10647     1
# 10743     1
# 10776     1
# std    144.477366  1.234520e+05  30160.384765   38337.353337   19.96748
# min      1.000000  8.300000e+01   1104.000000    5145.000000  -57.50000
# 25%    125.750000  1.190000e+04  19099.000000    7245.000000   -3.82500
# 50%    250.500000  2.500000e+04  46244.500000   11384.000000    1.90000
# 75%    375.250000  5.682525e+04  75045.000000   22605.250000    7.32500
# max    500.000000  2.300000e+06  98188.000000  485873.000000  197.30000
#
#             Profits        Assets  Totshequity
# count    500.000000  5.000000e+02     500.0000
# mean    1779.479800  8.038934e+04   13640.1470
# std     3937.558721  2.704257e+05   30523.1538
# min    -6177.000000  4.370000e+02  -12688.0000
# 25%      235.725000  8.436500e+03    1997.5000
# 50%      683.600000  1.932450e+04    4981.0000
# 75%     1770.775000  4.812600e+04   12467.7500
# max    45687.000000  3.287968e+06  283001.0000

# %%
df.describe(include='object')
# Out:
#           Title                Website      Sector  \
# count       500                    500         500
# unique      500                    499          21
# top     Walmart  http://www.abbott.com  Financials
# freq          1                      2          84
#
#                            Industry    Hqlocation               Hqaddr  \
# count                           500           500                  500
# unique                           73           246                  491
# top     Utilities: Gas and Electric  New York, NY  12300 Liberty Blvd.
# freq                             22            45                    2
#
#           Hqcity Hqstate         Hqtel              Ceo  \
# count        500     500           500              500
# unique       239      37           499              496
# top     New York      NY  650-857-1501  Gregory J. Goff
# freq          45      54             2                2
#
#                                             Ceo-title  \
# count                                             500
# unique                                             12
# top     President, Chief Executive Officer & Director
# freq                                              189
#
#                                      Address Ticker               Fullname  \
# count                                    500    500                    500
# unique                                   494    468                    500
# top     400 Atlantic St., Stamford, CT 06901   NFLX  Wal-Mart Stores, Inc.
# freq                                       2      3                      1
#
#        Prftchange
# count         500
# unique        377
# top           5.2
# freq            6

# %%
df["Profits"] = pd.to_numeric(df["Profits"], errors='coerce')

# %%
df.head(10)
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
# 5     6  UnitedHealth Group  http://www.unitedhealthgroup.com     230000
# 6     7          CVS Health          http://www.cvshealth.com     204000
# 7     8      General Motors                 http://www.gm.com     225000
# 8     9                AT&T                http://www.att.com     268540
# 9    10          Ford Motor               http://www.ford.com     201000
#
#                    Sector                                  Industry  \
# 0               Retailing                     General Merchandisers
# 1              Financials  Insurance: Property and Casualty (Stock)
# 2              Technology               Computers, Office Equipment
# 3                  Energy                        Petroleum Refining
# 4             Wholesalers                  Wholesalers: Health Care
# 5             Health Care   Health Care: Insurance and Managed Care
# 6             Health Care  Health Care: Pharmacy and Other Services
# 7  Motor Vehicles & Parts                  Motor Vehicles and Parts
# 8      Telecommunications                        Telecommunications
# 9  Motor Vehicles & Parts                  Motor Vehicles and Parts
#
#           Hqlocation                  Hqaddr         Hqcity Hqstate  Hqzip  \
# 0    Bentonville, AR     702 S.W. Eighth St.    Bentonville      AR  72716
